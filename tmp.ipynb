# %%
Level 3 的股票基金手續費是多少？
算給我看
用 USDT 買 0.5 BTC，VIP2 現貨 taker，算手續費與總成本，折合台幣。
# Out:
#   Cell In[1], line 1
#     Level 3 的股票基金手續費是多少？
#                        ^
# SyntaxError: invalid character '？' (U+FF1F)
